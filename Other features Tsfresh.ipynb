# %%
import numpy as np
import pandas as pd
# %matplotlib inline
import glob
from functools import reduce
import tsfresh
from tsfresh.utilities.dataframe_functions import impute
from tsfresh import extract_features, extract_relevant_features, select_features
from tsfresh.feature_extraction import ComprehensiveFCParameters

# %%
from tsfresh.feature_extraction import ComprehensiveFCParameters

# %%
settings = ComprehensiveFCParameters()

# %%
frame=pd.read_csv('/Users/mahnooshsadeghi/Desktop/PTSD/PTSD Data/Windowed Data/Windowed Participant2.csv')

# %%
#import matplotlib.pyplot as plt
#frame[frame['ptsd_moment'] == 1].plot(subplots=True, sharex=True, figsize=(10,10))
#plt.show()

# %%
frame
# Out:
#        Unnamed: 0        date      time     acc_x     acc_y     acc_z  \
# 0               1  2017-05-27  13:47:09  4.043807  2.724601  8.985438
# 1               2  2017-05-27  13:47:10  1.304840  2.882619  9.583989
# 2               3  2017-05-27  13:47:11  0.924162  3.371036  9.658209
# 3               4  2017-05-27  13:47:12  0.991200  1.575385  9.380483
# 4               5  2017-05-27  13:47:13  0.675165  1.580173  9.385271
# ...           ...         ...       ...       ...       ...       ...
# 51233      402534  2017-06-01  05:36:02  0.995988  2.458845  9.665392
# 51234      402535  2017-06-01  05:36:03  0.816423  5.001487  8.870517
# 51235      402536  2017-06-01  05:36:04  3.361459  8.358158  4.393360
# 51236      402537  2017-06-01  05:36:05  1.132457  9.780314  3.677494
# 51237      402538  2017-06-01  05:36:06  1.781286  4.987122  7.558495
#
#        linear_accel_x  linear_accel_y  linear_accel_z     hr  ptsd_moment  \
# ...

# %%
stress=frame.groupby('windowno', as_index=False)['ptsd_moment'].max()

# %%
stress=stress.rename(columns={"ptsd_moment": "stress"})

# %%
result = frame.merge(stress, on=['windowno'])

# %%
ts= result.drop(['date', 'participant', 'time', 'ptsd_moment'], axis=1)

# %%
ts=ts.dropna()

# %%
ts.isnull().sum()
# Out:
# Unnamed: 0        0
# acc_x             0
# acc_y             0
# acc_z             0
# linear_accel_x    0
# linear_accel_y    0
# linear_accel_z    0
# hr                0
# windowno          0
# stress            0
# dtype: int64

# %%
y=ts['stress']

# %%
X= ts.drop (['stress'], axis=1)

# %%
X.head()
# Out:
#    Unnamed: 0     acc_x     acc_y     acc_z  linear_accel_x  linear_accel_y  \
# 0           1  4.043807  2.724601  8.985438        2.658356        7.235031
# 1           2  1.304840  2.882619  9.583989        1.884308        9.742966
# 2           3  0.924162  3.371036  9.658209        2.562851        1.384254
# 3           4  0.991200  1.575385  9.380483        0.726669        1.036148
# 4           5  0.675165  1.580173  9.385271        1.414856        1.151978
#
#    linear_accel_z    hr  windowno
# 0        7.743027  69.0         1
# 1        4.920105  69.0         1
# 2        0.591415  69.0         1
# 3        0.563019  69.0         1
# 4        1.029694  69.0         1

# %%
features_filtered_direct = extract_features(X,column_id='windowno', column_sort='Unnamed: 0')
# Out:
# Feature Extraction: 100%|██████████| 20/20 [03:17<00:00,  9.86s/it]

# %%
features_filtered_direct.head()
# Out:
# variable  acc_x__abs_energy  acc_x__absolute_sum_of_changes  \
# id
# 1               4895.810248                       12.471392
# 2               5459.298744                        0.062248
# 3               5181.829161                        8.015780
# 4                 73.593934                       13.029246
# 1849             530.150326                       62.687383
#
# variable  acc_x__agg_autocorrelation__f_agg_"mean"__maxlag_40  \
# id
# 1                                                 -0.010048
# 2                                                 -0.027802
# 3                                                 -0.006366
# 4                                                 -0.134988
# 1849                                              -0.066638
#
# variable  acc_x__agg_autocorrelation__f_agg_"median"__maxlag_40  \
# id
# 1                                                 -0.060789
# 2                                                 -0.027795
# ...

# %%
from tsfresh import select_features
from tsfresh.utilities.dataframe_functions import impute

# %%
stressts=ts.groupby('windowno', as_index=False)['stress'].max()

# %%
new= features_filtered_direct.merge(stressts,left_on='id', right_on=['windowno'])

# %%
impute(new)
features_filtered = select_features(new, new['stress'])
# Out:
# //miniconda3/envs/PTSD/lib/python3.7/site-packages/tsfresh/utilities/dataframe_functions.py:164: FutureWarning: The 'get_values' method is deprecated and will be removed in a future version. Use '.values' or 'np.asarray(..)' instead.
#   data = df.get_values()
# WARNING:tsfresh.utilities.dataframe_functions:The columns ['acc_x__fft_coefficient__coeff_31__attr_"abs"'
#  'acc_x__fft_coefficient__coeff_31__attr_"angle"'
#  'acc_x__fft_coefficient__coeff_31__attr_"imag"' ...
#  'linear_accel_z__fft_coefficient__coeff_99__attr_"angle"'
#  'linear_accel_z__fft_coefficient__coeff_99__attr_"imag"'
#  'linear_accel_z__fft_coefficient__coeff_99__attr_"real"'] did not have any finite values. Filling with zeros.
# WARNING:tsfresh.feature_selection.relevance:Infered classification as machine learning task
# WARNING:tsfresh.feature_selection.relevance:[test_feature_significance] Feature acc_x__agg_linear_trend__f_agg_"max"__chunk_len_50__attr_"stderr" is constant
# ...

# %%
features_filtered
# Out:
#      stress  acc_y__number_crossing_m__m_1  \
# 0         1                            3.0
# 1         0                            0.0
# 2         1                            1.0
# 3         1                            0.0
# 4         1                            6.0
# ..      ...                            ...
# 950       0                            0.0
# 951       0                            0.0
# 952       0                            0.0
# 953       0                            4.0
# 954       1                            6.0
#
#      linear_accel_z__fft_aggregated__aggtype_"centroid"  \
# 0                                            10.889933
# 1                                             3.363240
# 2                                            10.116627
# 3                                             5.262783
# 4                                             7.652556
# ..                                                 ...
# ...

# %%
list (features_filtered.columns)
# Out:
# ['stress',
#  'acc_y__number_crossing_m__m_1',
#  'linear_accel_z__fft_aggregated__aggtype_"centroid"',
#  'linear_accel_x__ratio_beyond_r_sigma__r_3',
#  'linear_accel_z__fft_aggregated__aggtype_"skew"',
#  'acc_y__range_count__max_1__min_-1',
#  'linear_accel_y__fft_aggregated__aggtype_"centroid"',
#  'acc_y__change_quantiles__f_agg_"var"__isabs_True__qh_1.0__ql_0.2',
#  'acc_y__change_quantiles__f_agg_"var"__isabs_True__qh_1.0__ql_0.8',
#  'windowno',
#  'acc_y__change_quantiles__f_agg_"var"__isabs_True__qh_1.0__ql_0.4',
#  'acc_y__fft_aggregated__aggtype_"centroid"',
#  'linear_accel_y__fft_aggregated__aggtype_"skew"',
#  'linear_accel_x__fft_aggregated__aggtype_"centroid"',
#  'acc_y__change_quantiles__f_agg_"var"__isabs_False__qh_1.0__ql_0.2',
#  'acc_y__fft_coefficient__coeff_4__attr_"abs"',
#  'acc_y__change_quantiles__f_agg_"var"__isabs_False__qh_1.0__ql_0.8',
#  'acc_x__fft_aggregated__aggtype_"centroid"',
# ...
